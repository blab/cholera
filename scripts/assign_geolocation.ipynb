# %%
import pandas as pd
import numpy as np
import os

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
df = pd.read_csv("../data/metadata.tsv", sep = "\t")

# %%
df
# Out:
#       Unnamed: 0                   strain    virus                       Id  \
# 0              0  CNRVC990298_ATGTCA_L001  cholera  CNRVC990298_ATGTCA_L001
# 1              1  CNRVC990299_CCGTCC_L001  cholera  CNRVC990299_CCGTCC_L001
# 2              2  CNRVC940149_AGTCAA_L002  cholera  CNRVC940149_AGTCAA_L002
# 3              3               16244_6_48  cholera               16244_6#48
# 4              4               16244_6_49  cholera               16244_6#49
# ...          ...                      ...      ...                      ...
# 1394        1394                 CDCF3403  cholera                 CDCF3403
# 1395        1395                6437_7_23  cholera                6437_7#23
# 1396        1396                6437_7_21  cholera                6437_7#21
# 1397        1397                SRR227311  cholera                SRR227311
# 1398        1398                6437_7_22  cholera                6437_7#22
#
# ...

# %% [markdown]
# ## Region

# %%
north_america = ['Haiti']
europe = [ 'Albania',
 'France',
 'Germany',
 'Italy',
 'Portugal',
 'Romania',
 'Russian_Federation',
 'Slovakia',
 'Spain',
 'Ukraine']
south_america = [ 'Argentina',
 'Bolivia',
 'Brazil',
 'Chile',
 'Colombia',
 'Ecuador',
 'French_Guiana',
 'Mexico',
 'Peru']
asia = [ 'Afghanistan',
 'Bahrain',
 'Bangladesh',
 'Cambodia',
 'China',
 'Gaza',
 'India',
 'India_Nepal',
 'Indonesia',
 'Iran',
 'Iraq',
 'Israel',
 'Jerusalem',
 'Jordan',
 'Kurdistan',
 'Laos',
 'Lebanon',
 'Malaysia',
 'Myanmar',
 'Nepal',
 'Pakistan',
 'Palestine',
 'Philippines',
 'Sri_Lanka',
 'Thailand',
 'Turkey',
 'Viet_Nam'] ######### 
africa = [ 'Algeria',
 'Angola',
 'Benin',
 'Burkina Faso',
 'Burundi',
 'Cameroon',
 'Central_African_Republic',
 'Chad',
 'Comoros',
 "Cote_d'Ivoire",
 'Democratic_Republic_of_the_Congo',
 'Djibouti',
 'Egypt',
 'Equatorial Guinea',
 'Ethiopia',
 'Gabon',
 'Ghana',
 'Ghana_Nigeria',
 'Guinea',
 'Guinea_Bissau',
 'Kenya',
 'Liberia',
 'Libya',
 'Madagascar',
 'Malawi',
 'Mali',
 'Mauritania',
 'Morocco',
 'Mozambique',
 'Niger',
 'Nigeria',
 'Republic_of_South_Africa',
 'Republic_of_the_Congo',
 'Rwanda',
 'Sao_Tome',
 'Senegal',
 'Sierra Leone',
 'Somalia',
 'South_Africa',
 'South_Sudan',
 'Sudan',
 'Tanzania',
 'Togo',
 'Tunisia',
 'Uganda',
 'Yemen',
 'Zambia',
 'Zambia_Republic_of_South_Africa',
 'Zimbabwe']
oceania = [ 'Papua_New_Guinea']
unknown = ["Unknown"]

# %%
df["region"] = np.nan
df["region"][df.Country.isin(north_america)] = "North America"
df['region'][df.Country.isin(europe)] = "Europe"
df['region'][df.Country.isin(oceania)] = "Oceania"
df['region'][df.Country.isin(africa)] = "Africa"
df['region'][df.Country.isin(asia)] = "Asia"
df['region'][df.Country.isin(south_america)] = "South America"
df['region'][df.Country.isin(unknown)] = "Unknown" #######
# Out:
# /var/folders/qg/fh7xzf2n37b4hx2w3dr605l80000gn/T/ipykernel_38077/2300419114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["region"][df.Country.isin(north_america)] = "North America"

# %% [markdown]
# ## Subregion (UN Geoscheme)
# https://en.wikipedia.org/wiki/List_of_countries_by_the_United_Nations_geoscheme

# %%
southern_america = [ 'Peru',
                'Argentina',
                 'Bolivia',
                 'Brazil',
                  'Chile',
                  'Colombia',
                  'Ecuador',
                  'French_Guiana']
central_america = ["Mexico"]

carribbean = ["Haiti"]

### 

northern_africa = ['Algeria',
                   'Egypt',
                   'Morocco',
                   'Sudan',
                   'Tunisia',
                   'Libya']

eastern_africa = ['Ethiopia',
                 'Somalia',
                 'Madagascar',
                 'Uganda',
                 'Zambia_Republic_of_South_Africa',
                 'Zimbabwe',
                 'Tanzania',
                  'Malawi',
                   'Zambia',
                   'South_Sudan',
                   'Rwanda',
                  'Burundi',
                   'Comoros',
                  'Djibouti',
                   'Mozambique',
                   'Kenya']

central_africa = ['Central_African_Republic',
                 'Sao_Tome',
                 'Cameroon',
                  'Angola',
                  'Chad',
                  'Democratic_Republic_of_the_Congo',
                  'Republic_of_the_Congo',
                  'Equatorial_Guinea',
                  'Gabon',
                  'Guinea',
                  'Guinea_Bissau',
                  'Guinea-Bissau']

southern_africa = ['Zambia_Republic_of_South_Africa',
                   'Republic_of_South_Africa',
                   'South_Africa']

western_africa = ["Cote_d'Ivoire",
                  'Ghana',
                  'Ghana_Nigeria',
                  'Ghana/Nigeria',
                  'Senegal',
                  'Sierra_Leone',
                   'Togo',
                   'Benin',
                   'Burkina_Faso',
                   'Nigeria',
                   'Niger',
                   'Mauritania',
                   'Mali',
                   'Liberia']

### 

eastern_asia = ['China']

southeastern_asia = ['Viet_Nam',
                     'Cambodia',
                     'Laos',
                     'Malaysia',
                     'Myanmar',
                     'Philippines',
                     'Thailand',
                      'Indonesia']

southern_asia = ['Sri_Lanka',
                 'Bangladesh',
                 'India',
                 'India_Nepal',
                 'India/Nepal',
                 'Afghanistan',
                 'Iran',
                 'Nepal',
                 'Pakistan']

western_asia = ['Yemen',
                'Bahrain',
                 'Gaza',
                 'Iraq',
                 'Israel',
                 'Jerusalem',
                 'Jordan',
                 'Kurdistan',
                 'Lebanon',
                 'Palestine',
                 'Turkey']
###

eastern_europe = ['Romania',
                 'Russian_Federation',
                 'Ukraine',
                  'Slovakia']

southern_europe = ['Albania',
                  'Italy',
                   'Portugal',
                   'Spain']

western_europe = [ 'France',
                  'Germany']

oceania = [ 'Papua_New_Guinea']

# %%
df["subregion"] = np.nan

df["subregion"][df.Country.isin(southern_america)] = "South America"
df["subregion"][df.Country.isin(central_america)] = "Central America"
df["subregion"][df.Country.isin(carribbean)] = "Carribbean"
df["subregion"][df.Country.isin(northern_africa)] = "North Africa"
df["subregion"][df.Country.isin(eastern_africa)] = "East Africa"
df["subregion"][df.Country.isin(central_africa)] = "Central Africa"
df["subregion"][df.Country.isin(southern_africa)] = "Southern Africa"
df["subregion"][df.Country.isin(western_africa)] = "West Africa"
df["subregion"][df.Country.isin(eastern_asia)] = "East Asia"
df["subregion"][df.Country.isin(southeastern_asia)] = "Southeast Asia"
df["subregion"][df.Country.isin(southern_asia)] = "Southern Asia"
df["subregion"][df.Country.isin(western_asia)] = "West Asia"
df["subregion"][df.Country.isin(eastern_europe)] = "Eastern Europe"
df["subregion"][df.Country.isin(southern_europe)] = "Southern Europe"
df["subregion"][df.Country.isin(western_europe)] = "Western Europe"
df["subregion"][df.Country.isin(oceania)] = "Oceania"
df["subregion"][df.Country.isin(unknown)] = "Unknown"
# Out:
# /var/folders/qg/fh7xzf2n37b4hx2w3dr605l80000gn/T/ipykernel_38077/1050504069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["subregion"][df.Country.isin(southern_america)] = "South America"

# %%
df.region = df.region.str.replace(' ', '_')
df.Country = df.Country.str.replace(' ', '_')
df.subregion = df.subregion.str.replace(' ', '_')

# %%
df.Country.value_counts()
# Out:
# Mexico                              151
# India                               142
# Kenya                                76
# Democratic_Republic_of_the_Congo     75
# China                                71
#                                    ...
# Spain                                 1
# Jordan                                1
# Ghan_Nigeria                          1
# Jerusalem                             1
# South_Africa                          1
# Name: Country, Length: 98, dtype: int64

# %%
df.region.value_counts()
# Out:
# Africa           712
# Asia             415
# South_America    188
# North_America     27
# Europe            26
# Unknown            2
# Oceania            1
# Name: region, dtype: int64

# %%
df.subregion.value_counts()
# Out:
# Southern_Asia      269
# East_Africa        250
# Central_Africa     205
# West_Africa        180
# Central_America    151
# West_Asia           81
# East_Asia           71
# North_Africa        37
# South_America       37
# Southeast_Asia      36
# Carribbean          27
# Southern_Africa     25
# Eastern_Europe      13
# Southern_Europe     10
# Western_Europe       3
# Unknown              2
# Oceania              1
# Name: subregion, dtype: int64

# %%
df.to_csv("../../cholera_aws/data/metadata.tsv", sep = "\t")

# %%
df.to_csv("../data/metadata2.tsv", sep = "\t")
